# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Yazhini\Downloads\retail_store_sales.csv")

# %%
df
# Out:
#      Transaction_ID        Date Customer_ID  Age  Gender        Category  \
# 0                 1  2025-01-21       C1103   36    Male       Groceries
# 1                 2  2025-11-05       C1258   41  Female       Groceries
# 2                 3  2025-11-10       C1022   61    Male        Clothing
# 3                 4  2025-07-09       C1175   61    Male       Groceries
# 4                 5  2025-06-16       C1274   21    Male  Home & Kitchen
# ..              ...         ...         ...  ...     ...             ...
# 995             996  2025-08-27       C1020   35    Male        Clothing
# 996             997  2026-08-24       C1253   41  Female        Clothing
# 997             998  2026-01-29       C1042   38    Male     Electronics
# 998             999  2026-05-21       C1041   40    Male       Groceries
# 999            1000  2025-07-10       C1009   50    Male       Groceries
#
#         Product Region  Quantity     Price  Discount_Percent      Sales
# ...

# %%
df.head()
# Out:
#    Transaction_ID        Date Customer_ID  Age  Gender        Category  \
# 0               1  2025-01-21       C1103   36    Male       Groceries
# 1               2  2025-11-05       C1258   41  Female       Groceries
# 2               3  2025-11-10       C1022   61    Male        Clothing
# 3               4  2025-07-09       C1175   61    Male       Groceries
# 4               5  2025-06-16       C1274   21    Male  Home & Kitchen
#
#   Product Region  Quantity    Price  Discount_Percent     Sales
# 0  Coffee   East         5   958.00                20   3832.00
# 1  Coffee  South         5  3025.52                10  13614.84
# 2   Jeans  North         4   957.85                15   3256.69
# 3   Bread   West         7   740.49                15   4405.92
# 4   Mixer   West         3  4306.71                20  10336.10

# %%
df.tail()
# Out:
#      Transaction_ID        Date Customer_ID  Age  Gender     Category  \
# 995             996  2025-08-27       C1020   35    Male     Clothing
# 996             997  2026-08-24       C1253   41  Female     Clothing
# 997             998  2026-01-29       C1042   38    Male  Electronics
# 998             999  2026-05-21       C1041   40    Male    Groceries
# 999            1000  2025-07-10       C1009   50    Male    Groceries
#
#         Product Region  Quantity     Price  Discount_Percent      Sales
# 995       Jeans  North         5   2770.94                 5   13161.96
# 996       Shoes   West         4   3339.03                20   10684.90
# 997  Smartphone   West         3  39519.73                10  106703.27
# 998       Bread   West         3   2069.08                 0    6207.24
# 999      Coffee   West         1    919.12                 5     873.16

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Age', 'Gender', 'Category',
#        'Product', 'Region', 'Quantity', 'Price', 'Discount_Percent', 'Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer_ID       1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Gender            1000 non-null   object
#  5   Category          1000 non-null   object
#  6   Product           1000 non-null   object
#  7   Region            1000 non-null   object
#  8   Quantity          1000 non-null   int64
#  9   Price             1000 non-null   float64
#  10  Discount_Percent  1000 non-null   int64
#  11  Sales             1000 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#        Transaction_ID          Age     Quantity         Price  \
# count     1000.000000  1000.000000  1000.000000   1000.000000
# mean       500.500000    41.340000     3.981000   8056.248550
# std        288.819436    13.713222     1.977511  11867.373347
# min          1.000000    18.000000     1.000000     61.470000
# 25%        250.750000    30.000000     2.000000   1749.655000
# 50%        500.500000    41.000000     4.000000   3351.205000
# 75%        750.250000    53.000000     6.000000   4844.222500
# max       1000.000000    65.000000     7.000000  49977.240000
#
#        Discount_Percent          Sales
# count       1000.000000    1000.000000
# mean           9.930000   28443.059210
# std            7.197006   48894.541634
# min            0.000000      85.460000
# 25%            5.000000    4342.635000
# 50%           10.000000   10962.940000
# 75%           15.000000   22578.580000
# max           20.000000  289702.980000

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Age                 0
# Gender              0
# Category            0
# Product             0
# Region              0
# Quantity            0
# Price               0
# Discount_Percent    0
# Sales               0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100)
# Out:
# Transaction_ID      0.0
# Date                0.0
# Customer_ID         0.0
# Age                 0.0
# Gender              0.0
# Category            0.0
# Product             0.0
# Region              0.0
# Quantity            0.0
# Price               0.0
# Discount_Percent    0.0
# Sales               0.0
# dtype: float64

# %%
# Handle missing values 
df["Sales"] = df["Sales"].fillna(df["Sales"].median())
df["Category"] = df["Category"].fillna("Unknown")
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Age                 0
# Gender              0
# Category            0
# Product             0
# Region              0
# Quantity            0
# Price               0
# Discount_Percent    0
# Sales               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Transaction_ID        int64
# Date                 object
# Customer_ID          object
# Age                   int64
# Gender               object
# Category             object
# Product              object
# Region               object
# Quantity              int64
# Price               float64
# Discount_Percent      int64
# Sales               float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.dtypes
# Out:
# Transaction_ID               int64
# Date                datetime64[ns]
# Customer_ID                 object
# Age                          int64
# Gender                      object
# Category                    object
# Product                     object
# Region                      object
# Quantity                     int64
# Price                      float64
# Discount_Percent             int64
# Sales                      float64
# dtype: object

# %%
# Check unique values 

df["Category"].unique()
# Out:
# array(['Groceries', 'Clothing', 'Home & Kitchen', 'Electronics'],
#       dtype=object)

# %%
df["Category"].nunique()
# Out:
# 4

# %%
df["Region"].unique()

df["Category"].unique()
# Out:
# array(['Groceries', 'Clothing', 'Home & Kitchen', 'Electronics'],
#       dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Category
# Groceries         259
# Clothing          251
# Home & Kitchen    246
# Electronics       244
# Name: count, dtype: int64

# %%
df["Category"] = (df["Category"].str.strip().str.title())

# %%
df["Category"].value_counts()
# Out:
# Category
# Groceries         259
# Clothing          251
# Home & Kitchen    246
# Electronics       244
# Name: count, dtype: int64

# %%
df["Sales"] = df["Sales"].fillna(df["Sales"].mean())
df["Region"] = df["Region"].fillna(df["Region"].mode()[0])

# %%
# Duplicate values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
# Incorrect Data types 

df["Sales"] = pd.to_numeric(df["Sales"])

df["Date"] = pd.to_datetime(df["Date"])

# %%
# Inconsistent Categories 

df["Region"].nunique()
# Out:
# 4

# %%
df["Region"] = df["Region"].str.strip().str.title()

# %%
# Incorrect values  

df[df["Sales"] < 0 ]
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Date, Customer_ID, Age, Gender, Category, Product, Region, Quantity, Price, Discount_Percent, Sales]
# Index: []

# %%
# Data Validation 

df["Valid_Sales"] = df["Sales"] > 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer_ID       1000 non-null   object
#  3   Age               1000 non-null   int64
#  4   Gender            1000 non-null   object
#  5   Category          1000 non-null   object
#  6   Product           1000 non-null   object
#  7   Region            1000 non-null   object
#  8   Quantity          1000 non-null   int64
#  9   Price             1000 non-null   float64
#  10  Discount_Percent  1000 non-null   int64
#  11  Sales             1000 non-null   float64
#  12  Valid_Sales       1000 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(4), object(5)
# memory usage: 94.9+ KB

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Age                 0
# Gender              0
# Category            0
# Product             0
# Region              0
# Quantity            0
# Price               0
# Discount_Percent    0
# Sales               0
# Valid_Sales         0
# dtype: int64

# %%
df["Year"] = df["Date"].dt.year
df
# Out:
#      Transaction_ID       Date Customer_ID  Age  Gender        Category  \
# 0                 1 2025-01-21       C1103   36    Male       Groceries
# 1                 2 2025-11-05       C1258   41  Female       Groceries
# 2                 3 2025-11-10       C1022   61    Male        Clothing
# 3                 4 2025-07-09       C1175   61    Male       Groceries
# 4                 5 2025-06-16       C1274   21    Male  Home & Kitchen
# ..              ...        ...         ...  ...     ...             ...
# 995             996 2025-08-27       C1020   35    Male        Clothing
# 996             997 2026-08-24       C1253   41  Female        Clothing
# 997             998 2026-01-29       C1042   38    Male     Electronics
# 998             999 2026-05-21       C1041   40    Male       Groceries
# 999            1000 2025-07-10       C1009   50    Male       Groceries
#
#         Product Region  Quantity     Price  Discount_Percent      Sales  \
# ...

# %%
df
# Out:
#      Transaction_ID       Date Customer_ID  Age  Gender        Category  \
# 0                 1 2025-01-21       C1103   36    Male       Groceries
# 1                 2 2025-11-05       C1258   41  Female       Groceries
# 2                 3 2025-11-10       C1022   61    Male        Clothing
# 3                 4 2025-07-09       C1175   61    Male       Groceries
# 4                 5 2025-06-16       C1274   21    Male  Home & Kitchen
# ..              ...        ...         ...  ...     ...             ...
# 995             996 2025-08-27       C1020   35    Male        Clothing
# 996             997 2026-08-24       C1253   41  Female        Clothing
# 997             998 2026-01-29       C1042   38    Male     Electronics
# 998             999 2026-05-21       C1041   40    Male       Groceries
# 999            1000 2025-07-10       C1009   50    Male       Groceries
#
#         Product Region  Quantity     Price  Discount_Percent      Sales  \
# ...

# %%
# Numerical Columns
df["Sales"].describe()
# Out:
# count      1000.000000
# mean      28443.059210
# std       48894.541634
# min          85.460000
# 25%        4342.635000
# 50%       10962.940000
# 75%       22578.580000
# max      289702.980000
# Name: Sales, dtype: float64

# %%
# Categorical Columns 
df["Category"].value_counts()
# Out:
# Category
# Groceries         259
# Clothing          251
# Home & Kitchen    246
# Electronics       244
# Name: count, dtype: int64

# %%
plt.hist(df["Sales"])
plt.show()

# %%
sns.boxplot(x=df["Sales"])
plt.show()

# %%
# Distribution Analysis 

df["Sales"].mean()
df["Sales"].median()
df["Sales"].mode()
# Out:
# 0          85.46
# 1          88.16
# 2         104.61
# 3         114.92
# 4         118.70
#          ...
# 995    264043.27
# 996    266256.76
# 997    268827.72
# 998    288343.87
# 999    289702.98
# Name: Sales, Length: 1000, dtype: float64

# %%
df["Sales"].skew()
# Out:
# np.float64(2.9374943092703782)

# %%
df["Sales"].kurt()
# Out:
# np.float64(8.691009209081425)

# %%
# Outlier Analysis 

Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1 

lower_limit = Q1 - 1.5 * IQR 
upper_limit = Q3 + 1.5 * IQR 

outliers = df[
    (df["Sales"] < lower_limit) |
    (df["Sales"] > upper_limit)
]

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Age', 'Gender', 'Category',
#        'Product', 'Region', 'Quantity', 'Price', 'Discount_Percent', 'Sales',
#        'Valid_Sales', 'Year'],
#       dtype='object')

# %%
"Profit" in df.columns
# Out:
# False

# %%
df = pd.read_csv(r"C:\Users\Yazhini\Downloads\retail_store_sales.csv")

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Age', 'Gender', 'Category',
#        'Product', 'Region', 'Quantity', 'Price', 'Discount_Percent', 'Sales'],
#       dtype='object')

# %%
# Bivariate Analysis 

sns.scatterplot(data=df, x="Sales", y="Price")
plt.show()

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Clothing           2305600.26
# Electronics       21157549.02
# Groceries          2474076.88
# Home & Kitchen     2505833.05
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Price"].sum()
# Out:
# Region
# East     2426764.17
# North    2048571.39
# South    1909846.22
# West     1671066.77
# Name: Price, dtype: float64

# %%
# Multivariate Analysis 
###  Analyzing more than two variables 

df.groupby(["Region","Category"])["Sales"].sum()
# Out:
# Region  Category
# East    Clothing           757702.11
#         Electronics       6828829.96
#         Groceries          540723.90
#         Home & Kitchen     660461.92
# North   Clothing           491946.33
#         Electronics       5791437.37
#         Groceries          622145.45
#         Home & Kitchen     587402.36
# South   Clothing           494935.56
#         Electronics       4553446.37
#         Groceries          677240.26
#         Home & Kitchen     651893.61
# West    Clothing           561016.26
#         Electronics       3983835.32
#         Groceries          633967.27
#         Home & Kitchen     606075.16
# Name: Sales, dtype: float64

# %%
# Correlation Analysis 
numeric_df = df.select_dtypes(include=np.number)
numeric_df.corr()
# Out:
#                   Transaction_ID       Age  Quantity     Price  \
# Transaction_ID          1.000000  0.046082 -0.036086 -0.014155
# Age                     0.046082  1.000000  0.024416 -0.003604
# Quantity               -0.036086  0.024416  1.000000 -0.015124
# Price                  -0.014155 -0.003604 -0.015124  1.000000
# Discount_Percent        0.003653  0.012767 -0.003610  0.020181
# Sales                  -0.018208  0.003199  0.288360  0.844383
#
#                   Discount_Percent     Sales
# Transaction_ID            0.003653 -0.018208
# Age                       0.012767  0.003199
# Quantity                 -0.003610  0.288360
# Price                     0.020181  0.844383
# Discount_Percent          1.000000 -0.010322
# Sales                    -0.010322  1.000000

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    numeric_df.corr(),annot=True,cmap="coolwarm"
)
plt.show()

# %%
# Categorical Analysis 

category_sales = df.groupby(
    "Category")["Sales"].sum().sort_values(ascending=False)
category_sales
# Out:
# Category
# Electronics       21157549.02
# Home & Kitchen     2505833.05
# Groceries          2474076.88
# Clothing           2305600.26
# Name: Sales, dtype: float64

# %%
category_sales.plot(kind="bar")

plt.title("Sales by Category")

plt.xlabel("Category")

plt.ylabel("Sales")

plt.show()

# %%
product_sales = df.groupby(
    "Product"
)["Sales"].sum().sort_values(ascending=False)

product_sales
# Out:
# Product
# Headphones    5972414.71
# Laptop        5356054.47
# Smartphone    5099852.21
# Tablet        4729227.63
# Chair          676410.23
# Bread          667913.27
# Table          654001.16
# Coffee         640794.85
# Shoes          634256.67
# Rice           609932.26
# Cookware       598369.69
# Mixer          577051.97
# Jeans          575987.45
# Jacket         567972.63
# Milk           555436.50
# T-Shirt        527383.51
# Name: Sales, dtype: float64

# %%
# Region Analysis 

region_sales = df.groupby(
    "Region"
)["Sales"].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# East     8787717.89
# North    7492931.51
# South    6377515.80
# West     5784894.01
# Name: Sales, dtype: float64

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Age', 'Gender', 'Category',
#        'Product', 'Region', 'Quantity', 'Price', 'Discount_Percent', 'Sales'],
#       dtype='object')

# %%
sns.countplot(data=df, x="Discount_Percent")

plt.show()

# %%
df.dtypes
# Out:
# Transaction_ID        int64
# Date                 object
# Customer_ID          object
# Age                   int64
# Gender               object
# Category             object
# Product              object
# Region               object
# Quantity              int64
# Price               float64
# Discount_Percent      int64
# Sales               float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.dtypes
# Out:
# Transaction_ID               int64
# Date                datetime64[ns]
# Customer_ID                 object
# Age                          int64
# Gender                      object
# Category                    object
# Product                     object
# Region                      object
# Quantity                     int64
# Price                      float64
# Discount_Percent             int64
# Sales                      float64
# dtype: object

# %%
df["Year"] = df["Date"].dt.year
df
# Out:
#      Transaction_ID       Date Customer_ID  Age  Gender        Category  \
# 0                 1 2025-01-21       C1103   36    Male       Groceries
# 1                 2 2025-11-05       C1258   41  Female       Groceries
# 2                 3 2025-11-10       C1022   61    Male        Clothing
# 3                 4 2025-07-09       C1175   61    Male       Groceries
# 4                 5 2025-06-16       C1274   21    Male  Home & Kitchen
# ..              ...        ...         ...  ...     ...             ...
# 995             996 2025-08-27       C1020   35    Male        Clothing
# 996             997 2026-08-24       C1253   41  Female        Clothing
# 997             998 2026-01-29       C1042   38    Male     Electronics
# 998             999 2026-05-21       C1041   40    Male       Groceries
# 999            1000 2025-07-10       C1009   50    Male       Groceries
#
#         Product Region  Quantity     Price  Discount_Percent      Sales  Year
# ...

# %%
# Time Series Analysis 

df.groupby("Year")["Sales"].sum()
# Out:
# Year
# 2025    17337975.26
# 2026    11105083.95
# Name: Sales, dtype: float64
